# %%
# !git clone https://github.com/Iam-Divyesh/Watch_Prices.git
# Out:
# Cloning into 'Watch_Prices'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), 14.39 KiB | 4.80 MiB/s, done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
df = pd.read_csv("./Watch_Prices/smartwatches.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       Brand  Current Price  Original Price  Discount Percentage  \
# 0           0       noise        82990.0         89900.0             7.686318
# 1           1  fire-boltt         3799.0         16999.0            77.651627
# 2           2        boat         1999.0          7990.0            74.981227
# 3           3  fire-boltt         1799.0         19999.0            91.004550
# 4           4       noise         1599.0          4999.0            68.013603
#
#    Rating  Number OF Ratings                              Model Name  \
# 0     4.0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk
# 1     4.3            20788.0                                  BSW046
# 2     3.8            21724.0                               Wave Call
# 3     4.3            13244.0                                  BSW053
# 4     4.1            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk
#
#   Dial Shape Strap Color Strap Material Touchscreen  Battery Life (Days)  \
# ...

# %%
df = df.iloc[:, 1:]

# %%
df.head()
# Out:
#         Brand  Current Price  Original Price  Discount Percentage  Rating  \
# 0       noise        82990.0         89900.0             7.686318     4.0
# 1  fire-boltt         3799.0         16999.0            77.651627     4.3
# 2        boat         1999.0          7990.0            74.981227     3.8
# 3  fire-boltt         1799.0         19999.0            91.004550     4.3
# 4       noise         1599.0          4999.0            68.013603     4.1
#
#    Number OF Ratings                              Model Name Dial Shape  \
# 0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk        NaN
# 1            20788.0                                  BSW046        NaN
# 2            21724.0                               Wave Call        NaN
# 3            13244.0                                  BSW053        NaN
# 4            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk        NaN
#
#   Strap Color Strap Material Touchscreen  Battery Life (Days) Bluetooth  \
# ...

# %%
df.shape
# Out:
# (450, 15)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 440 entries, 0 to 449
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brand                440 non-null    object
#  1   Current Price        430 non-null    float64
#  2   Original Price       367 non-null    float64
#  3   Discount Percentage  367 non-null    float64
#  4   Rating               434 non-null    float64
#  5   Number OF Ratings    381 non-null    float64
#  6   Model Name           407 non-null    object
#  7   Dial Shape           327 non-null    object
#  8   Strap Color          327 non-null    object
#  9   Strap Material       374 non-null    object
#  10  Touchscreen          403 non-null    object
#  11  Battery Life (Days)  408 non-null    float64
#  12  Bluetooth            434 non-null    object
#  13  Display Size         410 non-null    object
#  14  Weight               254 non-null    object
# ...

# %%
numerical_data = [feature for feature in df.columns if df[feature].dtype != "object"]

# %%
numerical_data
# Out:
# ['Current Price',
#  'Original Price',
#  'Discount Percentage',
#  'Rating',
#  'Number OF Ratings',
#  'Battery Life (Days)']

# %%
continuous_data = [feature for feature in df.columns if df[feature].dtype == "object"]

# %%
continuous_data
# Out:
# ['Brand',
#  'Model Name',
#  'Dial Shape',
#  'Strap Color',
#  'Strap Material',
#  'Touchscreen',
#  'Bluetooth',
#  'Display Size',
#  'Weight']

# %%
df[numerical_data].describe()
# Out:
#        Current Price  Original Price  Discount Percentage      Rating  \
# count     430.000000      367.000000           367.000000  434.000000
# mean    12998.790698    14772.667575            47.491370    4.032949
# std     17888.717643    15619.947948            23.980218    0.556048
# min      1199.000000     1669.000000           -79.688436    1.000000
# 25%      2223.750000     5999.000000            32.698596    3.900000
# 50%      3999.000000     7999.000000            52.645433    4.100000
# 75%     17921.000000    18999.000000            66.677780    4.300000
# max    139990.000000    96390.000000            91.004550    5.000000
#
#        Number OF Ratings  Battery Life (Days)
# count         381.000000           408.000000
# mean        11398.406824            14.237377
# std         40882.373355             7.740915
# min             1.000000             0.750000
# 25%            68.000000             8.000000
# 50%           830.000000            17.500000
# ...

# %%
df[numerical_data].corr()
# Out:
#                      Current Price  Original Price  Discount Percentage  \
# Current Price             1.000000        0.970399            -0.625179
# Original Price            0.970399        1.000000            -0.506883
# Discount Percentage      -0.625179       -0.506883             1.000000
# Rating                    0.394874        0.332952            -0.223924
# Number OF Ratings        -0.139911       -0.135843             0.202925
# Battery Life (Days)       0.012320       -0.134343             0.019337
#
#                        Rating  Number OF Ratings  Battery Life (Days)
# Current Price        0.394874          -0.139911             0.012320
# Original Price       0.332952          -0.135843            -0.134343
# Discount Percentage -0.223924           0.202925             0.019337
# Rating               1.000000           0.054351            -0.094351
# Number OF Ratings    0.054351           1.000000             0.051378
# ...

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.8/309.8 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=3b543da3b2bf0632b57408f7bda11f444d8b3631eb4e6e069798212a047461dd
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
# ...

# %%
# !pip install --upgrade numba
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 12.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# distributed-ucxx-cu12 0.42.0 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.
# cuml-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.
# cudf-cu12 25.2.1 requires numba<0.61.0a0,>=0.59.1, but you have numba 0.61.2 which is incompatible.
# ...

# %%
import pandas_profiling as pp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-4afb823491c5> in <cell line: 0>()
# ----> 1 import pandas_profiling as pp
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/__init__.py in <module>
#       4 """
#       5
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/controller/pandas_decorator.py in <module>
#       2 from pandas import DataFrame
#       3
# ----> 4 from pandas_profiling.profile_report import ProfileReport
#       5
#       6
#
# /usr/local/lib/python3.11/dist-packages/pandas_profiling/profile_report.py in <module>
#       9 import yaml
#      10 from tqdm.auto import tqdm
# ---> 11 from visions import VisionsTypeset
#      12
# ...
